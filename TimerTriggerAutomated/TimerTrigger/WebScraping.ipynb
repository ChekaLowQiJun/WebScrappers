# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import pandas as pd
import requests

# %%
search_term = 'manga'
amazon_url = "https://www.amazon.sg/s?k={}".format(search_term)

# %%
client = uReq(amazon_url)
client

# %%
page_html = client.read()
client.close()

# %%
page_soup = soup(page_html)

# %%
span_tags_product_name = page_soup.findAll('span', {'class': 'a-size-base-plus a-color-base a-text-normal'})

# %%
product_names = []

for product_name in span_tags_product_name:
    product_names.append(product_name.text)

# %%
span_tags_prices = page_soup.findAll('span', {'class': "a-price", 'data-a-size': "xl"})

# %%
prices = []

for price in span_tags_prices:
    prices.append(price.text[:(len(price.text)//2)])

# %%
df = pd.DataFrame(product_names, prices)

# %%
df.to_csv("{}_prices.csv".format(search_term))

# %%
df
# Out:
#                                                           0
# S$36.27                       Homunculus (Omnibus) Vol. 1-2
# S$38.49       Yokohama Kaidashi Kikou: Omnibus Collection 2
# S$176.13  Demon Slayer Complete Box Set: Includes volume...
# S$22.68     Monster: The Perfect Edition, Vol. 1 (Volume 1)
# S$18.62                                        Goodbye, Eri
# S$31.30                             PTSD Radio 3 (Vol. 5-6)
# S$27.69            Don't Call it Mystery (Omnibus) Vol. 1-2
# S$22.71                               Solo Leveling, Vol. 5
# S$115.89     Toilet-bound Hanako-kun: First Stall: Volume 1
# S$25.85                       Solo Leveling, Vol. 1 (manga)
# S$13.29                    Sakamoto Days, Vol. 1 (Volume 1)
# S$19.00                                           Look Back
# S$33.99   Manga For The Beginner: Everything You Need to...
# S$32.78   Anime & Manga Digital Coloring Guide: Choose t...
# S$24.87                   Tombs: Junji Ito Story Collection
# S$15.61                     Spy x Family, Vol. 9 (Volume 9)
# S$17.97                              My Dress-Up Darling 01
# S$41.40       A Silent Voice Complete Collector's Edition 2
# S$19.94                                 The Garden of Words
# S$28.27                                     Vinland Saga 13
# S$40.86            No Longer Human Complete Edition (manga)
# S$21.66                      [Oshi No Ko], Vol. 1: Volume 1
# S$29.57           Fist of the North Star, Vol. 2 (Volume 2)
# S$13.29                    Sakamoto Days, Vol. 5 (Volume 5)
# S$44.56   The Girl From the Other Side: Siúil, a Rún Del...
# S$28.25   20th Century Boys: The Perfect Edition, Vol. 1...
# S$30.34                                    The Liminal Zone
# S$39.47   Naruto. La historia secreta de Kakashiº 01 (no...
# S$137.91                 Bungo Stray Dogs Manga Set Vol 1-8
# S$15.40                 Jujutsu Kaisen, Vol. 11 (Volume 11)
# S$14.93                     Spy x Family, Vol. 1 (Volume 1)
# S$30.48                            Goodnight Punpun, Vol. 1
# S$52.58                             Berserk Deluxe Volume 1
# S$67.47   The Quintessential Quintuplets Part 2 Manga Bo...
# S$23.71                      Boy's Abyss, Vol. 1 (Volume 1)
# S$60.75                               Vinland Saga Deluxe 1
# S$16.23                   Jujutsu Kaisen, Vol. 1 (Volume 1)
# S$35.97            Dissolving Classroom Collector's Edition
# S$18.77                  Tokyo Revengers (Omnibus) Vol. 1-2
# S$26.75                                             solanin
# S$9.80    Icy IM-35A Manga Manuscript Paper, A4, Thickne...
# S$19.42                                        The Gods Lie
# S$66.30                    Dementia 21 Box Set: Vols. 1 & 2
# S$17.69   Demon Slayer: Kimetsu no Yaiba, Vol. 1 (Volume 1)
# S$28.83                    Parasyte Full Color Collection 1
# S$22.48                                    Berserk Volume 1
# S$23.71                      Kaiju No. 8, Vol. 1 (Volume 1)
# S$55.43   Pokémon Adventures Red & Blue Box Set (Set Inc...
